# %% [markdown]
# # Parallel CNNs with Varied Loss Functions
#
# This notebook will attempt to replicate the model and train it as described in the paper, and then with a better loss function.

# %%
# Setup & Load Data
import pandas as pd 
import torch
import numpy as np
import matplotlib.pyplot as plt

device_2_data = pd.read_csv("processed-data/device_2_processed.csv").iloc[100:]
device_3_data = pd.read_csv("processed-data/device_3_processed.csv").iloc[100:]
device_4_data = pd.read_csv("processed-data/device_4_processed.csv").iloc[100:]
device_5_data = pd.read_csv("processed-data/device_5_processed.csv").iloc[100:]

# Normalize time for each device to count up from 0
device_2_data["time"] = device_2_data["timeEpoch"] - device_2_data["timeEpoch"].min()
device_3_data["time"] = device_3_data["timeEpoch"] - device_3_data["timeEpoch"].min()
device_4_data["time"] = device_4_data["timeEpoch"] - device_4_data["timeEpoch"].min()
device_5_data["time"] = device_5_data["timeEpoch"] - device_5_data["timeEpoch"].min()

# Calculate Delta Vth (baseline is first measurement after slicing)
device_2_data["Delta_Vt"] = device_2_data["Vt"] - device_2_data["Vt"].iloc[0]
device_3_data["Delta_Vt"] = device_3_data["Vt"] - device_3_data["Vt"].iloc[0]
device_4_data["Delta_Vt"] = device_4_data["Vt"] - device_4_data["Vt"].iloc[0]
device_5_data["Delta_Vt"] = device_5_data["Vt"] - device_5_data["Vt"].iloc[0]

# Normalize features to prevent activation explosion
# Compute statistics from training data
all_train = [device_3_data, device_4_data, device_5_data]
esw_mean = np.concatenate([d['Esw'].values for d in all_train]).mean()
esw_std = np.concatenate([d['Esw'].values for d in all_train]).std()
rth_mean = np.concatenate([d['Rth'].values for d in all_train]).mean()
rth_std = np.concatenate([d['Rth'].values for d in all_train]).std()
dv_mean = np.concatenate([d['Delta_Vt'].values for d in all_train]).mean()
dv_std = np.concatenate([d['Delta_Vt'].values for d in all_train]).std()

# Apply normalization to all datasets
for data in [device_2_data, device_3_data, device_4_data, device_5_data]:
    data["Esw"] = (data["Esw"] - esw_mean) / esw_std
    data["Rth"] = (data["Rth"] - rth_mean) / rth_std
    data["Delta_Vt"] = (data["Delta_Vt"] - dv_mean) / dv_std

# Use device 2 for dev, everything else for train
data_train = [device_3_data, device_4_data, device_5_data]
data_dev = device_2_data

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Model Definitions
rul_scale = 2000.0  # To normalize the RUL values to be bewteen 0 and 1, which Claude recommended might be a good idea...

# CausalConv written by Claude
class CausalConv1d(torch.nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, dilation=1):
        super().__init__()
        self.pad = (kernel_size - 1) * dilation  # left-pad only
        self.conv = torch.nn.Conv1d(in_channels, out_channels,
                                    kernel_size, dilation=dilation, padding=0)
    def forward(self, x):
        x = torch.nn.functional.pad(x, (self.pad, 0))
        return self.conv(x)

class RULModel(torch.nn.Module):
    """ Contains a CNN fed by Esw, an LSTM fed by Rth and Vt, and a cross attention layer that combines the CNN and LSTM outputs to predict RUL. """
    def __init__(self, input_size: int, hidden_size: int, num_layers: int):
        super(RULModel, self).__init__()
        self.cnnconv1=    CausalConv1d(in_channels=1, out_channels=hidden_size, kernel_size=7, dilation=16)
        self.cnnconv2=    CausalConv1d(in_channels=hidden_size, out_channels=hidden_size, kernel_size=5, dilation=1)
        self.cnnrelu =    torch.nn.ReLU()
        self.cnnbn = torch.nn.BatchNorm1d(hidden_size)
        self.lstm = torch.nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.attention = torch.nn.MultiheadAttention(embed_dim=hidden_size, num_heads=2, batch_first=True)
        self.fc = torch.nn.Linear(hidden_size, 1)

        self.cm_scale = torch.nn.Linear(1, 1)  # Scaling factor for coffin-manson predictions
        self.cm_material = torch.nn.Linear(1, 1)  # Scaling factor for coffin-manson predictions

    def forward(self, esw, rth_vt):
        # CNN branch for Esw
        # esw = esw.permute(0,2,1)  # Add channel dimension; suggested by Gemini
        # esw = esw.unsqueeze(1)  # Add channel dimension
        esw = esw.view(esw.size(0), 1, -1)  # Reshape to (1, 1, seq_len)
        rth_vt = rth_vt.view(rth_vt.size(0), -1, 2)  # Add batch dimension for LSTM

        cnn_out = self.cnnconv1(esw)
        cnn_out = self.cnnrelu(cnn_out)
        # cnn_out = self.cnnconv2(cnn_out)
        # cnn_out = self.cnnrelu(cnn_out)
        cnn_out = self.cnnbn(cnn_out)
        cnn_out = cnn_out.transpose(1,2)  # (batch, seq_len, hidden_size)
        
        # LSTM branch for Rth and Vt
        lstm_out, _ = self.lstm(rth_vt)
        
        # Cross attention between CNN and LSTM outputs
        seq_len = cnn_out.size(1)
        causal_mask = torch.triu(  # Causal mask from Claude
            torch.ones(seq_len, seq_len, device=cnn_out.device), diagonal=1
        ).bool()  # True = masked out

        attn_output, _ = self.attention(
            cnn_out, lstm_out, lstm_out,
            attn_mask=causal_mask
        )
        
        # Final RUL prediction using fused attention output
        rul_pred = self.fc(attn_output)  # Per-timestep predictions: (batch, seq_len, 1)
        
        return rul_pred

# %%
def train_model(model, data_train, data_dev, num_epochs=100, learning_rate=0.001, fancyloss=False):

    if fancyloss:
        # Init weights to reasonable values so fancy loss is not at a disadvantage.
        torch.nn.init.constant_(model.cm_material.weight, -2.5)
        torch.nn.init.constant_(model.cm_material.bias, 0.0)
        # Initialize cm_scale to identity (slope=1, bias=0)
        torch.nn.init.constant_(model.cm_scale.weight, 1.0)
        torch.nn.init.constant_(model.cm_scale.bias, 0.0)


    mseloss = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    allloss = []

    # move things to the device:
    model.to(device)
    mseloss.to(device)
    # data_dev = data_dev.to(device)
    # data_train = [d.to(device) for d in data_train]

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for device_data in data_train:
            # window_size = np.random.randint(256, 2048)  # Random window size
            # Claude helped with trasforming my code from individual runs to batching, which speeds things up tremendously!
            # i=0
            # esw_batch = torch.stack([
            #     torch.tensor(device_data.iloc[i:i+window_size]['Esw'].values, dtype=torch.float32)
            #     for window_size in range(8, len(device_data))
            # ]).to(device)  # (batch_size, window_size)
            
            # rth_vt_batch = torch.stack([
            #     torch.tensor(device_data.iloc[i:i+window_size][['Rth', 'Delta_Vt']].values, dtype=torch.float32)
            #     for window_size in range(8, len(device_data))
            # ]).to(device)  # (batch_size, window_size, 2)
            
            # rul_batch = torch.tensor([
            #     device_data.iloc[i+window_size-1]['RUL'] / rul_scale
            #     for window_size in range(8, len(device_data))
            # ], dtype=torch.float32).to(device)  # (batch_size,)

            esw = torch.tensor(device_data['Esw'].values, dtype=torch.float32).unsqueeze(0).to(device)
            rth_vt = torch.tensor(device_data[['Rth', 'Delta_Vt']].values, dtype=torch.float32).unsqueeze(0).to(device)

            # Get rul at the end of the window
            # rul = torch.tensor(device_data_window.iloc[-1]['RUL'], dtype=torch.float32).to(device) / rul_scale  # Normalize RUL to be between 0 and 1

            optimizer.zero_grad()
            # rul_pred = model(esw_batch, rth_vt_batch)
    
            rul_pred = model(esw, rth_vt)
            rul_true = torch.tensor(device_data['RUL'].values / rul_scale, dtype=torch.float32).to(device)  # (N,)
            
            # Use coffin-manson model
            # Subtract 25 degC from a sliding average of package temperature to get deltaT
            deltaT = torch.tensor(device_data['time_domain_packageTemperature'].values, dtype=torch.float32).to(device) - 25
            A = 0.1
            alpha = model.cm_material(torch.tensor([1.0], device=device)) if fancyloss else -2.5 # Learnable material parameter
            Nf = (A * deltaT.unsqueeze(-1) ** alpha)/ rul_scale

            loss = 0.7 * mseloss(rul_pred.squeeze(), rul_true) + 0.3 * torch.abs(rul_pred.squeeze() - model.cm_scale(Nf.view(-1, 1))).mean()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        # Evaluate on development set (full sequence like training)
        model.eval()
        dev_loss = 0.0
        with torch.no_grad():
            data_dev_window = data_dev

            esw_dev = torch.tensor(data_dev_window['Esw'].values, dtype=torch.float32).unsqueeze(0).to(device)
            rth_vt_dev = torch.tensor(data_dev_window[['Rth', 'Delta_Vt']].values, dtype=torch.float32).unsqueeze(0).to(device)

            # Get full RUL sequence for dev set (not just final value)
            rul_dev_full = torch.tensor(data_dev_window['RUL'].values / rul_scale, dtype=torch.float32).to(device)
            rul_pred_dev = model(esw_dev, rth_vt_dev)

            # Use coffin-manson model
            # Subtract 25 degC from a sliding average of package temperature to get deltaT
            deltaT = torch.tensor(data_dev_window['time_domain_packageTemperature'].values, dtype=torch.float32).to(device) - 25
            A = .1
            alpha = model.cm_material(torch.tensor([1.0], device=device)) if fancyloss else -2.5  # Learnable material parameter
            Nf = (A * deltaT.unsqueeze(-1) ** alpha)/ rul_scale

            # Compute loss over full sequence like training
            dev_loss = 0.7 * mseloss(rul_pred_dev.squeeze(), rul_dev_full) + 0.3 * torch.abs(rul_pred_dev.squeeze()  - model.cm_scale(Nf.view(-1, 1))).mean()

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss/len(data_train):.4f}, Dev Loss: {dev_loss:.4f}")
        allloss += [(train_loss/len(data_train), dev_loss/len(data_dev))]

    return allloss

# %%
modela = RULModel(input_size=2, hidden_size=32, num_layers=2)
modelb = RULModel(input_size=2, hidden_size=32, num_layers=2)
modelb.load_state_dict(modela.state_dict())  # Start with same weights for fair comparison

lossa = train_model(modela, data_train, data_dev, num_epochs=256, learning_rate=0.0005, fancyloss=False)
lossb = train_model(modelb, data_train, data_dev, num_epochs=256, learning_rate=0.0005, fancyloss=True)
# Out:
# Epoch 1/256, Train Loss: 0.1368, Dev Loss: 0.1263
# Epoch 2/256, Train Loss: 0.1332, Dev Loss: 0.1237
# Epoch 3/256, Train Loss: 0.1304, Dev Loss: 0.1218
# Epoch 4/256, Train Loss: 0.1283, Dev Loss: 0.1205
# Epoch 5/256, Train Loss: 0.1267, Dev Loss: 0.1196
# Epoch 6/256, Train Loss: 0.1256, Dev Loss: 0.1191
# Epoch 7/256, Train Loss: 0.1249, Dev Loss: 0.1187
# Epoch 8/256, Train Loss: 0.1243, Dev Loss: 0.1182
# Epoch 9/256, Train Loss: 0.1236, Dev Loss: 0.1175
# Epoch 10/256, Train Loss: 0.1228, Dev Loss: 0.1166
# Epoch 11/256, Train Loss: 0.1219, Dev Loss: 0.1156
# Epoch 12/256, Train Loss: 0.1209, Dev Loss: 0.1146
# Epoch 13/256, Train Loss: 0.1198, Dev Loss: 0.1135
# Epoch 14/256, Train Loss: 0.1186, Dev Loss: 0.1123
# Epoch 15/256, Train Loss: 0.1172, Dev Loss: 0.1109
# Epoch 16/256, Train Loss: 0.1156, Dev Loss: 0.1092
# Epoch 17/256, Train Loss: 0.1136, Dev Loss: 0.1072
# Epoch 18/256, Train Loss: 0.1114, Dev Loss: 0.1048
# Epoch 19/256, Train Loss: 0.1091, Dev Loss: 0.1024
# Epoch 20/256, Train Loss: 0.1071, Dev Loss: 0.1002
# Epoch 21/256, Train Loss: 0.1058, Dev Loss: 0.0989
# Epoch 22/256, Train Loss: 0.1049, Dev Loss: 0.0985
# Epoch 23/256, Train Loss: 0.1043, Dev Loss: 0.0987
# Epoch 24/256, Train Loss: 0.1038, Dev Loss: 0.0987
# Epoch 25/256, Train Loss: 0.1032, Dev Loss: 0.0981
# Epoch 26/256, Train Loss: 0.1025, Dev Loss: 0.0972
# Epoch 27/256, Train Loss: 0.1017, Dev Loss: 0.0962
# Epoch 28/256, Train Loss: 0.1011, Dev Loss: 0.0955
# Epoch 29/256, Train Loss: 0.1006, Dev Loss: 0.0948
# Epoch 30/256, Train Loss: 0.1000, Dev Loss: 0.0944
# Epoch 31/256, Train Loss: 0.0995, Dev Loss: 0.0939
# Epoch 32/256, Train Loss: 0.0990, Dev Loss: 0.0934
# Epoch 33/256, Train Loss: 0.0985, Dev Loss: 0.0929
# Epoch 34/256, Train Loss: 0.0980, Dev Loss: 0.0924
# Epoch 35/256, Train Loss: 0.0974, Dev Loss: 0.0918
# Epoch 36/256, Train Loss: 0.0969, Dev Loss: 0.0913
# Epoch 37/256, Train Loss: 0.0964, Dev Loss: 0.0908
# Epoch 38/256, Train Loss: 0.0959, Dev Loss: 0.0903
# Epoch 39/256, Train Loss: 0.0955, Dev Loss: 0.0898
# Epoch 40/256, Train Loss: 0.0950, Dev Loss: 0.0894
# Epoch 41/256, Train Loss: 0.0945, Dev Loss: 0.0889
# Epoch 42/256, Train Loss: 0.0940, Dev Loss: 0.0884
# Epoch 43/256, Train Loss: 0.0935, Dev Loss: 0.0880
# Epoch 44/256, Train Loss: 0.0930, Dev Loss: 0.0875
# Epoch 45/256, Train Loss: 0.0926, Dev Loss: 0.0870
# Epoch 46/256, Train Loss: 0.0921, Dev Loss: 0.0866
# Epoch 47/256, Train Loss: 0.0916, Dev Loss: 0.0861
# Epoch 48/256, Train Loss: 0.0912, Dev Loss: 0.0857
# Epoch 49/256, Train Loss: 0.0907, Dev Loss: 0.0853
# Epoch 50/256, Train Loss: 0.0903, Dev Loss: 0.0848
# Epoch 51/256, Train Loss: 0.0898, Dev Loss: 0.0844
# Epoch 52/256, Train Loss: 0.0894, Dev Loss: 0.0839
# Epoch 53/256, Train Loss: 0.0889, Dev Loss: 0.0835
# Epoch 54/256, Train Loss: 0.0885, Dev Loss: 0.0831
# Epoch 55/256, Train Loss: 0.0881, Dev Loss: 0.0827
# Epoch 56/256, Train Loss: 0.0876, Dev Loss: 0.0822
# Epoch 57/256, Train Loss: 0.0872, Dev Loss: 0.0818
# Epoch 58/256, Train Loss: 0.0868, Dev Loss: 0.0814
# Epoch 59/256, Train Loss: 0.0863, Dev Loss: 0.0810
# Epoch 60/256, Train Loss: 0.0859, Dev Loss: 0.0806
# Epoch 61/256, Train Loss: 0.0855, Dev Loss: 0.0802
# Epoch 62/256, Train Loss: 0.0850, Dev Loss: 0.0798
# Epoch 63/256, Train Loss: 0.0846, Dev Loss: 0.0794
# Epoch 64/256, Train Loss: 0.0842, Dev Loss: 0.0790
# Epoch 65/256, Train Loss: 0.0838, Dev Loss: 0.0786
# Epoch 66/256, Train Loss: 0.0834, Dev Loss: 0.0782
# Epoch 67/256, Train Loss: 0.0829, Dev Loss: 0.0778
# Epoch 68/256, Train Loss: 0.0826, Dev Loss: 0.0774
# Epoch 69/256, Train Loss: 0.0821, Dev Loss: 0.0770
# Epoch 70/256, Train Loss: 0.0817, Dev Loss: 0.0766
# Epoch 71/256, Train Loss: 0.0813, Dev Loss: 0.0763
# Epoch 72/256, Train Loss: 0.0809, Dev Loss: 0.0758
# Epoch 73/256, Train Loss: 0.0805, Dev Loss: 0.0755
# Epoch 74/256, Train Loss: 0.0801, Dev Loss: 0.0751
# Epoch 75/256, Train Loss: 0.0797, Dev Loss: 0.0747
# Epoch 76/256, Train Loss: 0.0793, Dev Loss: 0.0743
# Epoch 77/256, Train Loss: 0.0789, Dev Loss: 0.0739
# Epoch 78/256, Train Loss: 0.0785, Dev Loss: 0.0735
# Epoch 79/256, Train Loss: 0.0781, Dev Loss: 0.0732
# Epoch 80/256, Train Loss: 0.0777, Dev Loss: 0.0728
# Epoch 81/256, Train Loss: 0.0773, Dev Loss: 0.0724
# Epoch 82/256, Train Loss: 0.0769, Dev Loss: 0.0721
# Epoch 83/256, Train Loss: 0.0765, Dev Loss: 0.0717
# Epoch 84/256, Train Loss: 0.0761, Dev Loss: 0.0713
# Epoch 85/256, Train Loss: 0.0757, Dev Loss: 0.0709
# Epoch 86/256, Train Loss: 0.0753, Dev Loss: 0.0706
# Epoch 87/256, Train Loss: 0.0750, Dev Loss: 0.0701
# Epoch 88/256, Train Loss: 0.0746, Dev Loss: 0.0698
# Epoch 89/256, Train Loss: 0.0742, Dev Loss: 0.0694
# Epoch 90/256, Train Loss: 0.0738, Dev Loss: 0.0690
# Epoch 91/256, Train Loss: 0.0734, Dev Loss: 0.0687
# Epoch 92/256, Train Loss: 0.0730, Dev Loss: 0.0683
# Epoch 93/256, Train Loss: 0.0726, Dev Loss: 0.0680
# Epoch 94/256, Train Loss: 0.0723, Dev Loss: 0.0676
# Epoch 95/256, Train Loss: 0.0719, Dev Loss: 0.0673
# Epoch 96/256, Train Loss: 0.0715, Dev Loss: 0.0669
# Epoch 97/256, Train Loss: 0.0711, Dev Loss: 0.0665
# Epoch 98/256, Train Loss: 0.0708, Dev Loss: 0.0662
# Epoch 99/256, Train Loss: 0.0704, Dev Loss: 0.0658
# Epoch 100/256, Train Loss: 0.0700, Dev Loss: 0.0655
# Epoch 101/256, Train Loss: 0.0696, Dev Loss: 0.0652
# Epoch 102/256, Train Loss: 0.0693, Dev Loss: 0.0649
# Epoch 103/256, Train Loss: 0.0689, Dev Loss: 0.0646
# Epoch 104/256, Train Loss: 0.0685, Dev Loss: 0.0643
# Epoch 105/256, Train Loss: 0.0682, Dev Loss: 0.0640
# Epoch 106/256, Train Loss: 0.0678, Dev Loss: 0.0637
# Epoch 107/256, Train Loss: 0.0674, Dev Loss: 0.0634
# Epoch 108/256, Train Loss: 0.0671, Dev Loss: 0.0631
# Epoch 109/256, Train Loss: 0.0667, Dev Loss: 0.0628
# Epoch 110/256, Train Loss: 0.0663, Dev Loss: 0.0625
# Epoch 111/256, Train Loss: 0.0660, Dev Loss: 0.0622
# Epoch 112/256, Train Loss: 0.0656, Dev Loss: 0.0619
# Epoch 113/256, Train Loss: 0.0652, Dev Loss: 0.0616
# Epoch 114/256, Train Loss: 0.0649, Dev Loss: 0.0613
# Epoch 115/256, Train Loss: 0.0645, Dev Loss: 0.0610
# Epoch 116/256, Train Loss: 0.0641, Dev Loss: 0.0607
# Epoch 117/256, Train Loss: 0.0638, Dev Loss: 0.0603
# Epoch 118/256, Train Loss: 0.0634, Dev Loss: 0.0600
# Epoch 119/256, Train Loss: 0.0630, Dev Loss: 0.0596
# Epoch 120/256, Train Loss: 0.0627, Dev Loss: 0.0592
# Epoch 121/256, Train Loss: 0.0623, Dev Loss: 0.0590
# Epoch 122/256, Train Loss: 0.0620, Dev Loss: 0.0584
# Epoch 123/256, Train Loss: 0.0616, Dev Loss: 0.0584
# Epoch 124/256, Train Loss: 0.0613, Dev Loss: 0.0578
# Epoch 125/256, Train Loss: 0.0610, Dev Loss: 0.0577
# Epoch 126/256, Train Loss: 0.0606, Dev Loss: 0.0575
# Epoch 127/256, Train Loss: 0.0602, Dev Loss: 0.0572
# Epoch 128/256, Train Loss: 0.0599, Dev Loss: 0.0568
# Epoch 129/256, Train Loss: 0.0595, Dev Loss: 0.0567
# Epoch 130/256, Train Loss: 0.0592, Dev Loss: 0.0561
# Epoch 131/256, Train Loss: 0.0589, Dev Loss: 0.0561
# Epoch 132/256, Train Loss: 0.0586, Dev Loss: 0.0554
# Epoch 133/256, Train Loss: 0.0582, Dev Loss: 0.0555
# Epoch 134/256, Train Loss: 0.0579, Dev Loss: 0.0549
# Epoch 135/256, Train Loss: 0.0575, Dev Loss: 0.0549
# Epoch 136/256, Train Loss: 0.0572, Dev Loss: 0.0543
# Epoch 137/256, Train Loss: 0.0569, Dev Loss: 0.0545
# Epoch 138/256, Train Loss: 0.0566, Dev Loss: 0.0534
# Epoch 139/256, Train Loss: 0.0563, Dev Loss: 0.0541
# Epoch 140/256, Train Loss: 0.0561, Dev Loss: 0.0526
# Epoch 141/256, Train Loss: 0.0557, Dev Loss: 0.0533
# Epoch 142/256, Train Loss: 0.0554, Dev Loss: 0.0522
# Epoch 143/256, Train Loss: 0.0550, Dev Loss: 0.0526
# Epoch 144/256, Train Loss: 0.0548, Dev Loss: 0.0515
# Epoch 145/256, Train Loss: 0.0544, Dev Loss: 0.0520
# Epoch 146/256, Train Loss: 0.0542, Dev Loss: 0.0508
# Epoch 147/256, Train Loss: 0.0539, Dev Loss: 0.0514
# Epoch 148/256, Train Loss: 0.0536, Dev Loss: 0.0503
# Epoch 149/256, Train Loss: 0.0533, Dev Loss: 0.0507
# Epoch 150/256, Train Loss: 0.0530, Dev Loss: 0.0497
# Epoch 151/256, Train Loss: 0.0527, Dev Loss: 0.0501
# Epoch 152/256, Train Loss: 0.0524, Dev Loss: 0.0492
# Epoch 153/256, Train Loss: 0.0521, Dev Loss: 0.0496
# Epoch 154/256, Train Loss: 0.0519, Dev Loss: 0.0485
# Epoch 155/256, Train Loss: 0.0516, Dev Loss: 0.0491
# Epoch 156/256, Train Loss: 0.0513, Dev Loss: 0.0480
# Epoch 157/256, Train Loss: 0.0510, Dev Loss: 0.0485
# Epoch 158/256, Train Loss: 0.0508, Dev Loss: 0.0474
# Epoch 159/256, Train Loss: 0.0504, Dev Loss: 0.0480
# Epoch 160/256, Train Loss: 0.0502, Dev Loss: 0.0469
# Epoch 161/256, Train Loss: 0.0499, Dev Loss: 0.0474
# Epoch 162/256, Train Loss: 0.0497, Dev Loss: 0.0464
# Epoch 163/256, Train Loss: 0.0493, Dev Loss: 0.0469
# Epoch 164/256, Train Loss: 0.0491, Dev Loss: 0.0458
# Epoch 165/256, Train Loss: 0.0488, Dev Loss: 0.0464
# Epoch 166/256, Train Loss: 0.0486, Dev Loss: 0.0453
# Epoch 167/256, Train Loss: 0.0483, Dev Loss: 0.0458
# Epoch 168/256, Train Loss: 0.0481, Dev Loss: 0.0448
# Epoch 169/256, Train Loss: 0.0477, Dev Loss: 0.0453
# Epoch 170/256, Train Loss: 0.0475, Dev Loss: 0.0443
# Epoch 171/256, Train Loss: 0.0472, Dev Loss: 0.0448
# Epoch 172/256, Train Loss: 0.0470, Dev Loss: 0.0437
# Epoch 173/256, Train Loss: 0.0467, Dev Loss: 0.0444
# Epoch 174/256, Train Loss: 0.0465, Dev Loss: 0.0432
# Epoch 175/256, Train Loss: 0.0462, Dev Loss: 0.0439
# Epoch 176/256, Train Loss: 0.0460, Dev Loss: 0.0427
# Epoch 177/256, Train Loss: 0.0457, Dev Loss: 0.0434
# Epoch 178/256, Train Loss: 0.0455, Dev Loss: 0.0422
# Epoch 179/256, Train Loss: 0.0452, Dev Loss: 0.0429
# Epoch 180/256, Train Loss: 0.0450, Dev Loss: 0.0417
# Epoch 181/256, Train Loss: 0.0447, Dev Loss: 0.0425
# Epoch 182/256, Train Loss: 0.0445, Dev Loss: 0.0412
# Epoch 183/256, Train Loss: 0.0442, Dev Loss: 0.0420
# Epoch 184/256, Train Loss: 0.0441, Dev Loss: 0.0408
# Epoch 185/256, Train Loss: 0.0437, Dev Loss: 0.0415
# Epoch 186/256, Train Loss: 0.0436, Dev Loss: 0.0403
# Epoch 187/256, Train Loss: 0.0432, Dev Loss: 0.0410
# Epoch 188/256, Train Loss: 0.0431, Dev Loss: 0.0398
# Epoch 189/256, Train Loss: 0.0428, Dev Loss: 0.0406
# Epoch 190/256, Train Loss: 0.0426, Dev Loss: 0.0394
# Epoch 191/256, Train Loss: 0.0423, Dev Loss: 0.0402
# Epoch 192/256, Train Loss: 0.0422, Dev Loss: 0.0390
# Epoch 193/256, Train Loss: 0.0418, Dev Loss: 0.0397
# Epoch 194/256, Train Loss: 0.0417, Dev Loss: 0.0386
# Epoch 195/256, Train Loss: 0.0414, Dev Loss: 0.0391
# Epoch 196/256, Train Loss: 0.0412, Dev Loss: 0.0382
# Epoch 197/256, Train Loss: 0.0409, Dev Loss: 0.0386
# Epoch 198/256, Train Loss: 0.0408, Dev Loss: 0.0377
# Epoch 199/256, Train Loss: 0.0405, Dev Loss: 0.0385
# Epoch 200/256, Train Loss: 0.0404, Dev Loss: 0.0371
# Epoch 201/256, Train Loss: 0.0401, Dev Loss: 0.0384
# Epoch 202/256, Train Loss: 0.0400, Dev Loss: 0.0368
# Epoch 203/256, Train Loss: 0.0396, Dev Loss: 0.0376
# Epoch 204/256, Train Loss: 0.0395, Dev Loss: 0.0366
# Epoch 205/256, Train Loss: 0.0392, Dev Loss: 0.0371
# Epoch 206/256, Train Loss: 0.0390, Dev Loss: 0.0363
# Epoch 207/256, Train Loss: 0.0387, Dev Loss: 0.0363
# Epoch 208/256, Train Loss: 0.0385, Dev Loss: 0.0358
# Epoch 209/256, Train Loss: 0.0383, Dev Loss: 0.0356
# Epoch 210/256, Train Loss: 0.0381, Dev Loss: 0.0354
# Epoch 211/256, Train Loss: 0.0379, Dev Loss: 0.0356
# Epoch 212/256, Train Loss: 0.0378, Dev Loss: 0.0346
# Epoch 213/256, Train Loss: 0.0376, Dev Loss: 0.0357
# Epoch 214/256, Train Loss: 0.0375, Dev Loss: 0.0341
# Epoch 215/256, Train Loss: 0.0374, Dev Loss: 0.0351
# Epoch 216/256, Train Loss: 0.0371, Dev Loss: 0.0338
# Epoch 217/256, Train Loss: 0.0369, Dev Loss: 0.0344
# Epoch 218/256, Train Loss: 0.0366, Dev Loss: 0.0336
# Epoch 219/256, Train Loss: 0.0365, Dev Loss: 0.0342
# Epoch 220/256, Train Loss: 0.0363, Dev Loss: 0.0332
# Epoch 221/256, Train Loss: 0.0361, Dev Loss: 0.0339
# Epoch 222/256, Train Loss: 0.0360, Dev Loss: 0.0328
# Epoch 223/256, Train Loss: 0.0358, Dev Loss: 0.0335
# Epoch 224/256, Train Loss: 0.0356, Dev Loss: 0.0324
# Epoch 225/256, Train Loss: 0.0354, Dev Loss: 0.0331
# Epoch 226/256, Train Loss: 0.0353, Dev Loss: 0.0321
# Epoch 227/256, Train Loss: 0.0351, Dev Loss: 0.0328
# Epoch 228/256, Train Loss: 0.0349, Dev Loss: 0.0319
# Epoch 229/256, Train Loss: 0.0347, Dev Loss: 0.0324
# Epoch 230/256, Train Loss: 0.0346, Dev Loss: 0.0315
# Epoch 231/256, Train Loss: 0.0344, Dev Loss: 0.0322
# Epoch 232/256, Train Loss: 0.0343, Dev Loss: 0.0312
# Epoch 233/256, Train Loss: 0.0341, Dev Loss: 0.0319
# Epoch 234/256, Train Loss: 0.0340, Dev Loss: 0.0309
# Epoch 235/256, Train Loss: 0.0337, Dev Loss: 0.0315
# Epoch 236/256, Train Loss: 0.0336, Dev Loss: 0.0306
# Epoch 237/256, Train Loss: 0.0334, Dev Loss: 0.0311
# Epoch 238/256, Train Loss: 0.0333, Dev Loss: 0.0304
# Epoch 239/256, Train Loss: 0.0331, Dev Loss: 0.0307
# Epoch 240/256, Train Loss: 0.0330, Dev Loss: 0.0301
# Epoch 241/256, Train Loss: 0.0327, Dev Loss: 0.0303
# Epoch 242/256, Train Loss: 0.0326, Dev Loss: 0.0298
# Epoch 243/256, Train Loss: 0.0324, Dev Loss: 0.0300
# Epoch 244/256, Train Loss: 0.0323, Dev Loss: 0.0296
# Epoch 245/256, Train Loss: 0.0321, Dev Loss: 0.0297
# Epoch 246/256, Train Loss: 0.0320, Dev Loss: 0.0294
# Epoch 247/256, Train Loss: 0.0318, Dev Loss: 0.0294
# Epoch 248/256, Train Loss: 0.0317, Dev Loss: 0.0291
# Epoch 249/256, Train Loss: 0.0315, Dev Loss: 0.0290
# Epoch 250/256, Train Loss: 0.0314, Dev Loss: 0.0289
# Epoch 251/256, Train Loss: 0.0312, Dev Loss: 0.0287
# Epoch 252/256, Train Loss: 0.0311, Dev Loss: 0.0288
# Epoch 253/256, Train Loss: 0.0310, Dev Loss: 0.0284
# Epoch 254/256, Train Loss: 0.0309, Dev Loss: 0.0284
# Epoch 255/256, Train Loss: 0.0307, Dev Loss: 0.0283
# Epoch 256/256, Train Loss: 0.0306, Dev Loss: 0.0280
# Epoch 1/256, Train Loss: 0.1021, Dev Loss: 0.0823
# Epoch 2/256, Train Loss: 0.0850, Dev Loss: 0.0717
# Epoch 3/256, Train Loss: 0.0787, Dev Loss: 0.0705
# Epoch 4/256, Train Loss: 0.0773, Dev Loss: 0.0697
# Epoch 5/256, Train Loss: 0.0762, Dev Loss: 0.0690
# Epoch 6/256, Train Loss: 0.0754, Dev Loss: 0.0685
# Epoch 7/256, Train Loss: 0.0747, Dev Loss: 0.0680
# Epoch 8/256, Train Loss: 0.0740, Dev Loss: 0.0676
# Epoch 9/256, Train Loss: 0.0735, Dev Loss: 0.0671
# Epoch 10/256, Train Loss: 0.0729, Dev Loss: 0.0666
# Epoch 11/256, Train Loss: 0.0723, Dev Loss: 0.0661
# Epoch 12/256, Train Loss: 0.0716, Dev Loss: 0.0654
# Epoch 13/256, Train Loss: 0.0709, Dev Loss: 0.0647
# Epoch 14/256, Train Loss: 0.0702, Dev Loss: 0.0640
# Epoch 15/256, Train Loss: 0.0693, Dev Loss: 0.0632
# Epoch 16/256, Train Loss: 0.0684, Dev Loss: 0.0623
# Epoch 17/256, Train Loss: 0.0674, Dev Loss: 0.0613
# Epoch 18/256, Train Loss: 0.0663, Dev Loss: 0.0601
# Epoch 19/256, Train Loss: 0.0650, Dev Loss: 0.0588
# Epoch 20/256, Train Loss: 0.0635, Dev Loss: 0.0573
# Epoch 21/256, Train Loss: 0.0618, Dev Loss: 0.0555
# Epoch 22/256, Train Loss: 0.0598, Dev Loss: 0.0535
# Epoch 23/256, Train Loss: 0.0579, Dev Loss: 0.0524
# Epoch 24/256, Train Loss: 0.0573, Dev Loss: 0.0525
# Epoch 25/256, Train Loss: 0.0574, Dev Loss: 0.0520
# Epoch 26/256, Train Loss: 0.0571, Dev Loss: 0.0512
# Epoch 27/256, Train Loss: 0.0563, Dev Loss: 0.0505
# Epoch 28/256, Train Loss: 0.0556, Dev Loss: 0.0503
# Epoch 29/256, Train Loss: 0.0553, Dev Loss: 0.0504
# Epoch 30/256, Train Loss: 0.0548, Dev Loss: 0.0507
# Epoch 31/256, Train Loss: 0.0544, Dev Loss: 0.0505
# Epoch 32/256, Train Loss: 0.0540, Dev Loss: 0.0499
# Epoch 33/256, Train Loss: 0.0536, Dev Loss: 0.0494
# Epoch 34/256, Train Loss: 0.0533, Dev Loss: 0.0491
# Epoch 35/256, Train Loss: 0.0530, Dev Loss: 0.0490
# Epoch 36/256, Train Loss: 0.0527, Dev Loss: 0.0488
# Epoch 37/256, Train Loss: 0.0524, Dev Loss: 0.0484
# Epoch 38/256, Train Loss: 0.0521, Dev Loss: 0.0481
# Epoch 39/256, Train Loss: 0.0518, Dev Loss: 0.0479
# Epoch 40/256, Train Loss: 0.0515, Dev Loss: 0.0477
# Epoch 41/256, Train Loss: 0.0512, Dev Loss: 0.0474
# Epoch 42/256, Train Loss: 0.0509, Dev Loss: 0.0471
# Epoch 43/256, Train Loss: 0.0506, Dev Loss: 0.0468
# Epoch 44/256, Train Loss: 0.0503, Dev Loss: 0.0465
# Epoch 45/256, Train Loss: 0.0501, Dev Loss: 0.0461
# Epoch 46/256, Train Loss: 0.0498, Dev Loss: 0.0459
# Epoch 47/256, Train Loss: 0.0495, Dev Loss: 0.0456
# Epoch 48/256, Train Loss: 0.0492, Dev Loss: 0.0453
# Epoch 49/256, Train Loss: 0.0489, Dev Loss: 0.0450
# Epoch 50/256, Train Loss: 0.0487, Dev Loss: 0.0448
# Epoch 51/256, Train Loss: 0.0484, Dev Loss: 0.0445
# Epoch 52/256, Train Loss: 0.0481, Dev Loss: 0.0442
# Epoch 53/256, Train Loss: 0.0478, Dev Loss: 0.0439
# Epoch 54/256, Train Loss: 0.0476, Dev Loss: 0.0436
# Epoch 55/256, Train Loss: 0.0473, Dev Loss: 0.0434
# Epoch 56/256, Train Loss: 0.0470, Dev Loss: 0.0431
# Epoch 57/256, Train Loss: 0.0467, Dev Loss: 0.0428
# Epoch 58/256, Train Loss: 0.0465, Dev Loss: 0.0426
# Epoch 59/256, Train Loss: 0.0462, Dev Loss: 0.0423
# Epoch 60/256, Train Loss: 0.0459, Dev Loss: 0.0420
# Epoch 61/256, Train Loss: 0.0457, Dev Loss: 0.0418
# Epoch 62/256, Train Loss: 0.0454, Dev Loss: 0.0415
# Epoch 63/256, Train Loss: 0.0452, Dev Loss: 0.0413
# Epoch 64/256, Train Loss: 0.0449, Dev Loss: 0.0410
# Epoch 65/256, Train Loss: 0.0446, Dev Loss: 0.0408
# Epoch 66/256, Train Loss: 0.0444, Dev Loss: 0.0405
# Epoch 67/256, Train Loss: 0.0441, Dev Loss: 0.0403
# Epoch 68/256, Train Loss: 0.0439, Dev Loss: 0.0400
# Epoch 69/256, Train Loss: 0.0436, Dev Loss: 0.0398
# Epoch 70/256, Train Loss: 0.0434, Dev Loss: 0.0395
# Epoch 71/256, Train Loss: 0.0431, Dev Loss: 0.0393
# Epoch 72/256, Train Loss: 0.0429, Dev Loss: 0.0390
# Epoch 73/256, Train Loss: 0.0426, Dev Loss: 0.0388
# Epoch 74/256, Train Loss: 0.0424, Dev Loss: 0.0385
# Epoch 75/256, Train Loss: 0.0421, Dev Loss: 0.0383
# Epoch 76/256, Train Loss: 0.0419, Dev Loss: 0.0381
# Epoch 77/256, Train Loss: 0.0417, Dev Loss: 0.0378
# Epoch 78/256, Train Loss: 0.0414, Dev Loss: 0.0376
# Epoch 79/256, Train Loss: 0.0412, Dev Loss: 0.0374
# Epoch 80/256, Train Loss: 0.0409, Dev Loss: 0.0371
# Epoch 81/256, Train Loss: 0.0407, Dev Loss: 0.0369
# Epoch 82/256, Train Loss: 0.0405, Dev Loss: 0.0367
# Epoch 83/256, Train Loss: 0.0402, Dev Loss: 0.0364
# Epoch 84/256, Train Loss: 0.0400, Dev Loss: 0.0362
# Epoch 85/256, Train Loss: 0.0398, Dev Loss: 0.0360
# Epoch 86/256, Train Loss: 0.0396, Dev Loss: 0.0358
# Epoch 87/256, Train Loss: 0.0393, Dev Loss: 0.0356
# Epoch 88/256, Train Loss: 0.0391, Dev Loss: 0.0353
# Epoch 89/256, Train Loss: 0.0389, Dev Loss: 0.0351
# Epoch 90/256, Train Loss: 0.0387, Dev Loss: 0.0349
# Epoch 91/256, Train Loss: 0.0384, Dev Loss: 0.0347
# Epoch 92/256, Train Loss: 0.0382, Dev Loss: 0.0345
# Epoch 93/256, Train Loss: 0.0380, Dev Loss: 0.0343
# Epoch 94/256, Train Loss: 0.0378, Dev Loss: 0.0340
# Epoch 95/256, Train Loss: 0.0376, Dev Loss: 0.0338
# Epoch 96/256, Train Loss: 0.0374, Dev Loss: 0.0336
# Epoch 97/256, Train Loss: 0.0372, Dev Loss: 0.0334
# Epoch 98/256, Train Loss: 0.0369, Dev Loss: 0.0332
# Epoch 99/256, Train Loss: 0.0367, Dev Loss: 0.0330
# Epoch 100/256, Train Loss: 0.0365, Dev Loss: 0.0328
# Epoch 101/256, Train Loss: 0.0363, Dev Loss: 0.0326
# Epoch 102/256, Train Loss: 0.0361, Dev Loss: 0.0325
# Epoch 103/256, Train Loss: 0.0359, Dev Loss: 0.0323
# Epoch 104/256, Train Loss: 0.0357, Dev Loss: 0.0321
# Epoch 105/256, Train Loss: 0.0355, Dev Loss: 0.0319
# Epoch 106/256, Train Loss: 0.0353, Dev Loss: 0.0318
# Epoch 107/256, Train Loss: 0.0351, Dev Loss: 0.0316
# Epoch 108/256, Train Loss: 0.0349, Dev Loss: 0.0315
# Epoch 109/256, Train Loss: 0.0347, Dev Loss: 0.0312
# Epoch 110/256, Train Loss: 0.0345, Dev Loss: 0.0312
# Epoch 111/256, Train Loss: 0.0343, Dev Loss: 0.0310
# Epoch 112/256, Train Loss: 0.0341, Dev Loss: 0.0309
# Epoch 113/256, Train Loss: 0.0340, Dev Loss: 0.0307
# Epoch 114/256, Train Loss: 0.0338, Dev Loss: 0.0306
# Epoch 115/256, Train Loss: 0.0336, Dev Loss: 0.0303
# Epoch 116/256, Train Loss: 0.0334, Dev Loss: 0.0303
# Epoch 117/256, Train Loss: 0.0333, Dev Loss: 0.0298
# Epoch 118/256, Train Loss: 0.0331, Dev Loss: 0.0304
# Epoch 119/256, Train Loss: 0.0330, Dev Loss: 0.0293
# Epoch 120/256, Train Loss: 0.0328, Dev Loss: 0.0298
# Epoch 121/256, Train Loss: 0.0326, Dev Loss: 0.0291
# Epoch 122/256, Train Loss: 0.0324, Dev Loss: 0.0295
# Epoch 123/256, Train Loss: 0.0323, Dev Loss: 0.0287
# Epoch 124/256, Train Loss: 0.0321, Dev Loss: 0.0293
# Epoch 125/256, Train Loss: 0.0320, Dev Loss: 0.0284
# Epoch 126/256, Train Loss: 0.0317, Dev Loss: 0.0289
# Epoch 127/256, Train Loss: 0.0316, Dev Loss: 0.0282
# Epoch 128/256, Train Loss: 0.0314, Dev Loss: 0.0285
# Epoch 129/256, Train Loss: 0.0313, Dev Loss: 0.0279
# Epoch 130/256, Train Loss: 0.0311, Dev Loss: 0.0282
# Epoch 131/256, Train Loss: 0.0310, Dev Loss: 0.0275
# Epoch 132/256, Train Loss: 0.0309, Dev Loss: 0.0284
# Epoch 133/256, Train Loss: 0.0307, Dev Loss: 0.0270
# Epoch 134/256, Train Loss: 0.0305, Dev Loss: 0.0278
# Epoch 135/256, Train Loss: 0.0304, Dev Loss: 0.0269
# Epoch 136/256, Train Loss: 0.0302, Dev Loss: 0.0273
# Epoch 137/256, Train Loss: 0.0301, Dev Loss: 0.0267
# Epoch 138/256, Train Loss: 0.0299, Dev Loss: 0.0271
# Epoch 139/256, Train Loss: 0.0298, Dev Loss: 0.0262
# Epoch 140/256, Train Loss: 0.0297, Dev Loss: 0.0273
# Epoch 141/256, Train Loss: 0.0296, Dev Loss: 0.0259
# Epoch 142/256, Train Loss: 0.0293, Dev Loss: 0.0266
# Epoch 143/256, Train Loss: 0.0292, Dev Loss: 0.0259
# Epoch 144/256, Train Loss: 0.0290, Dev Loss: 0.0261
# Epoch 145/256, Train Loss: 0.0289, Dev Loss: 0.0257
# Epoch 146/256, Train Loss: 0.0287, Dev Loss: 0.0257
# Epoch 147/256, Train Loss: 0.0286, Dev Loss: 0.0254
# Epoch 148/256, Train Loss: 0.0285, Dev Loss: 0.0253
# Epoch 149/256, Train Loss: 0.0283, Dev Loss: 0.0253
# Epoch 150/256, Train Loss: 0.0282, Dev Loss: 0.0249
# Epoch 151/256, Train Loss: 0.0280, Dev Loss: 0.0250
# Epoch 152/256, Train Loss: 0.0279, Dev Loss: 0.0250
# Epoch 153/256, Train Loss: 0.0278, Dev Loss: 0.0245
# Epoch 154/256, Train Loss: 0.0277, Dev Loss: 0.0245
# Epoch 155/256, Train Loss: 0.0275, Dev Loss: 0.0248
# Epoch 156/256, Train Loss: 0.0274, Dev Loss: 0.0241
# Epoch 157/256, Train Loss: 0.0273, Dev Loss: 0.0241
# Epoch 158/256, Train Loss: 0.0271, Dev Loss: 0.0244
# Epoch 159/256, Train Loss: 0.0271, Dev Loss: 0.0238
# Epoch 160/256, Train Loss: 0.0269, Dev Loss: 0.0239
# Epoch 161/256, Train Loss: 0.0268, Dev Loss: 0.0243
# Epoch 162/256, Train Loss: 0.0268, Dev Loss: 0.0232
# Epoch 163/256, Train Loss: 0.0267, Dev Loss: 0.0237
# Epoch 164/256, Train Loss: 0.0265, Dev Loss: 0.0235
# Epoch 165/256, Train Loss: 0.0265, Dev Loss: 0.0230
# Epoch 166/256, Train Loss: 0.0263, Dev Loss: 0.0234
# Epoch 167/256, Train Loss: 0.0262, Dev Loss: 0.0233
# Epoch 168/256, Train Loss: 0.0260, Dev Loss: 0.0232
# Epoch 169/256, Train Loss: 0.0259, Dev Loss: 0.0230
# Epoch 170/256, Train Loss: 0.0258, Dev Loss: 0.0226
# Epoch 171/256, Train Loss: 0.0259, Dev Loss: 0.0224
# Epoch 172/256, Train Loss: 0.0259, Dev Loss: 0.0234
# Epoch 173/256, Train Loss: 0.0257, Dev Loss: 0.0223
# Epoch 174/256, Train Loss: 0.0256, Dev Loss: 0.0237
# Epoch 175/256, Train Loss: 0.0256, Dev Loss: 0.0222
# Epoch 176/256, Train Loss: 0.0254, Dev Loss: 0.0232
# Epoch 177/256, Train Loss: 0.0254, Dev Loss: 0.0224
# Epoch 178/256, Train Loss: 0.0253, Dev Loss: 0.0227
# Epoch 179/256, Train Loss: 0.0251, Dev Loss: 0.0222
# Epoch 180/256, Train Loss: 0.0249, Dev Loss: 0.0224
# Epoch 181/256, Train Loss: 0.0249, Dev Loss: 0.0221
# Epoch 182/256, Train Loss: 0.0248, Dev Loss: 0.0218
# Epoch 183/256, Train Loss: 0.0247, Dev Loss: 0.0222
# Epoch 184/256, Train Loss: 0.0247, Dev Loss: 0.0219
# Epoch 185/256, Train Loss: 0.0246, Dev Loss: 0.0219
# Epoch 186/256, Train Loss: 0.0245, Dev Loss: 0.0217
# Epoch 187/256, Train Loss: 0.0244, Dev Loss: 0.0216
# Epoch 188/256, Train Loss: 0.0245, Dev Loss: 0.0219
# Epoch 189/256, Train Loss: 0.0247, Dev Loss: 0.0217
# Epoch 190/256, Train Loss: 0.0243, Dev Loss: 0.0215
# Epoch 191/256, Train Loss: 0.0245, Dev Loss: 0.0215
# Epoch 192/256, Train Loss: 0.0243, Dev Loss: 0.0210
# Epoch 193/256, Train Loss: 0.0242, Dev Loss: 0.0219
# Epoch 194/256, Train Loss: 0.0242, Dev Loss: 0.0210
# Epoch 195/256, Train Loss: 0.0243, Dev Loss: 0.0219
# Epoch 196/256, Train Loss: 0.0242, Dev Loss: 0.0207
# Epoch 197/256, Train Loss: 0.0242, Dev Loss: 0.0219
# Epoch 198/256, Train Loss: 0.0241, Dev Loss: 0.0212
# Epoch 199/256, Train Loss: 0.0244, Dev Loss: 0.0208
# Epoch 200/256, Train Loss: 0.0240, Dev Loss: 0.0225
# Epoch 201/256, Train Loss: 0.0241, Dev Loss: 0.0207
# Epoch 202/256, Train Loss: 0.0241, Dev Loss: 0.0211
# Epoch 203/256, Train Loss: 0.0238, Dev Loss: 0.0218
# Epoch 204/256, Train Loss: 0.0238, Dev Loss: 0.0204
# Epoch 205/256, Train Loss: 0.0237, Dev Loss: 0.0218
# Epoch 206/256, Train Loss: 0.0237, Dev Loss: 0.0206
# Epoch 207/256, Train Loss: 0.0235, Dev Loss: 0.0206
# Epoch 208/256, Train Loss: 0.0234, Dev Loss: 0.0208
# Epoch 209/256, Train Loss: 0.0233, Dev Loss: 0.0203
# Epoch 210/256, Train Loss: 0.0234, Dev Loss: 0.0215
# Epoch 211/256, Train Loss: 0.0234, Dev Loss: 0.0201
# Epoch 212/256, Train Loss: 0.0232, Dev Loss: 0.0206
# Epoch 213/256, Train Loss: 0.0230, Dev Loss: 0.0202
# Epoch 214/256, Train Loss: 0.0229, Dev Loss: 0.0206
# Epoch 215/256, Train Loss: 0.0230, Dev Loss: 0.0201
# Epoch 216/256, Train Loss: 0.0228, Dev Loss: 0.0205
# Epoch 217/256, Train Loss: 0.0229, Dev Loss: 0.0201
# Epoch 218/256, Train Loss: 0.0227, Dev Loss: 0.0201
# Epoch 219/256, Train Loss: 0.0228, Dev Loss: 0.0201
# Epoch 220/256, Train Loss: 0.0227, Dev Loss: 0.0204
# Epoch 221/256, Train Loss: 0.0228, Dev Loss: 0.0198
# Epoch 222/256, Train Loss: 0.0229, Dev Loss: 0.0205
# Epoch 223/256, Train Loss: 0.0227, Dev Loss: 0.0196
# Epoch 224/256, Train Loss: 0.0226, Dev Loss: 0.0202
# Epoch 225/256, Train Loss: 0.0224, Dev Loss: 0.0196
# Epoch 226/256, Train Loss: 0.0224, Dev Loss: 0.0200
# Epoch 227/256, Train Loss: 0.0224, Dev Loss: 0.0197
# Epoch 228/256, Train Loss: 0.0223, Dev Loss: 0.0199
# Epoch 229/256, Train Loss: 0.0224, Dev Loss: 0.0197
# Epoch 230/256, Train Loss: 0.0222, Dev Loss: 0.0196
# Epoch 231/256, Train Loss: 0.0221, Dev Loss: 0.0195
# Epoch 232/256, Train Loss: 0.0222, Dev Loss: 0.0197
# Epoch 233/256, Train Loss: 0.0222, Dev Loss: 0.0193
# Epoch 234/256, Train Loss: 0.0224, Dev Loss: 0.0200
# Epoch 235/256, Train Loss: 0.0224, Dev Loss: 0.0192
# Epoch 236/256, Train Loss: 0.0226, Dev Loss: 0.0204
# Epoch 237/256, Train Loss: 0.0224, Dev Loss: 0.0197
# Epoch 238/256, Train Loss: 0.0226, Dev Loss: 0.0191
# Epoch 239/256, Train Loss: 0.0223, Dev Loss: 0.0212
# Epoch 240/256, Train Loss: 0.0228, Dev Loss: 0.0203
# Epoch 241/256, Train Loss: 0.0222, Dev Loss: 0.0191
# Epoch 242/256, Train Loss: 0.0221, Dev Loss: 0.0207
# Epoch 243/256, Train Loss: 0.0225, Dev Loss: 0.0194
# Epoch 244/256, Train Loss: 0.0225, Dev Loss: 0.0195
# Epoch 245/256, Train Loss: 0.0223, Dev Loss: 0.0201
# Epoch 246/256, Train Loss: 0.0220, Dev Loss: 0.0193
# Epoch 247/256, Train Loss: 0.0225, Dev Loss: 0.0190
# Epoch 248/256, Train Loss: 0.0220, Dev Loss: 0.0212
# Epoch 249/256, Train Loss: 0.0226, Dev Loss: 0.0202
# Epoch 250/256, Train Loss: 0.0221, Dev Loss: 0.0189
# Epoch 251/256, Train Loss: 0.0218, Dev Loss: 0.0200
# Epoch 252/256, Train Loss: 0.0219, Dev Loss: 0.0191
# Epoch 253/256, Train Loss: 0.0217, Dev Loss: 0.0194
# Epoch 254/256, Train Loss: 0.0217, Dev Loss: 0.0194
# Epoch 255/256, Train Loss: 0.0216, Dev Loss: 0.0189
# Epoch 256/256, Train Loss: 0.0218, Dev Loss: 0.0196

# %%
# plot train, dev loss on separate y-axes:
plt.title("Train and Dev Loss Over Epochs")
plt.xlabel("Epoch")
plt.plot([l[0] for l in lossa], label="Train Loss, Vanilla", linestyle='--', color='orange')
plt.plot([l[0] for l in lossb], label="Train Loss, Multiple Dilation", linestyle='--', color='red')
plt.ylabel("Train Loss")
plt.twinx()
plt.plot([l[1].cpu() for l in lossa], label="Vanilla", color='orange')
plt.plot([l[1].cpu() for l in lossb], label="Fit loss function", color='red')
plt.ylabel("Dev Loss")
plt.legend(loc="upper right")
plt.grid()
plt.show()

# %%
modela.eval()
modelb.eval()
with torch.no_grad():
    esw_dev = torch.tensor(data_dev['Esw'].values, dtype=torch.float32).unsqueeze(0).to(device)
    rth_vt_dev = torch.tensor(data_dev[['Rth', 'Delta_Vt']].values, dtype=torch.float32).unsqueeze(0).to(device)
    
    rula_pred_dev = modela(esw_dev, rth_vt_dev)  # (1, seq_len, 1)
    rulb_pred_dev = modelb(esw_dev, rth_vt_dev)  # (1, seq_len, 1)
    rul_true_dev = data_dev['RUL'].values  # (seq_len,)
    rula_pred_values = rula_pred_dev.squeeze().cpu().numpy() * rul_scale  # (seq_len,)
    rulb_pred_values = rulb_pred_dev.squeeze().cpu().numpy() * rul_scale  # (seq_len,)

# Also plot predicted and true side by side over time
plt.figure(figsize=(12, 6))
plt.plot(data_dev['time'], rul_true_dev, label="True RUL")
plt.plot(data_dev['time'], rula_pred_values, label="Predicted RUL (Original)")
plt.plot(data_dev['time'], rulb_pred_values, label="Predicted RUL (Adaptive Loss Funtion)")
plt.xlabel("Time (s)")
plt.ylabel("RUL")
plt.legend()
plt.title("Predicted and True RUL Over Time on \"Development Set\" Device")
plt.grid()
plt.show()
