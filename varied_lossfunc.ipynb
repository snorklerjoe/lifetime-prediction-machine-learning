# %% [markdown]
# # Parallel CNNs with Varied Loss Functions
#
# This notebook will attempt to replicate the model and train it as described in the paper, and then with a better loss function.

# %%
# Setup & Load Data
import pandas as pd 
import torch
import numpy as np
import matplotlib.pyplot as plt

device_2_data = pd.read_csv("processed-data/device_2_processed.csv").iloc[100:]
device_3_data = pd.read_csv("processed-data/device_3_processed.csv").iloc[100:]
device_4_data = pd.read_csv("processed-data/device_4_processed.csv").iloc[100:]
device_5_data = pd.read_csv("processed-data/device_5_processed.csv").iloc[100:]

# Normalize time for each device to count up from 0
device_2_data["time"] = device_2_data["timeEpoch"] - device_2_data["timeEpoch"].min()
device_3_data["time"] = device_3_data["timeEpoch"] - device_3_data["timeEpoch"].min()
device_4_data["time"] = device_4_data["timeEpoch"] - device_4_data["timeEpoch"].min()
device_5_data["time"] = device_5_data["timeEpoch"] - device_5_data["timeEpoch"].min()

# Calculate Delta Vth (baseline is first measurement after slicing)
device_2_data["Delta_Vt"] = device_2_data["Vt"] - device_2_data["Vt"].iloc[0]
device_3_data["Delta_Vt"] = device_3_data["Vt"] - device_3_data["Vt"].iloc[0]
device_4_data["Delta_Vt"] = device_4_data["Vt"] - device_4_data["Vt"].iloc[0]
device_5_data["Delta_Vt"] = device_5_data["Vt"] - device_5_data["Vt"].iloc[0]

# Normalize features to prevent activation explosion
# Compute statistics from training data
all_train = [device_3_data, device_4_data, device_5_data]
esw_mean = np.concatenate([d['Esw'].values for d in all_train]).mean()
esw_std = np.concatenate([d['Esw'].values for d in all_train]).std()
rth_mean = np.concatenate([d['Rth'].values for d in all_train]).mean()
rth_std = np.concatenate([d['Rth'].values for d in all_train]).std()
dv_mean = np.concatenate([d['Delta_Vt'].values for d in all_train]).mean()
dv_std = np.concatenate([d['Delta_Vt'].values for d in all_train]).std()

# Apply normalization to all datasets
for data in [device_2_data, device_3_data, device_4_data, device_5_data]:
    data["Esw"] = (data["Esw"] - esw_mean) / esw_std
    data["Rth"] = (data["Rth"] - rth_mean) / rth_std
    data["Delta_Vt"] = (data["Delta_Vt"] - dv_mean) / dv_std

# Use device 2 for dev, everything else for train
data_train = [device_3_data, device_4_data, device_5_data]
data_dev = device_2_data

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Model Definitions
rul_scale = 2000.0  # To normalize the RUL values to be bewteen 0 and 1, which Claude recommended might be a good idea...

# CausalConv written by Claude
class CausalConv1d(torch.nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, dilation=1):
        super().__init__()
        self.pad = (kernel_size - 1) * dilation  # left-pad only
        self.conv = torch.nn.Conv1d(in_channels, out_channels,
                                    kernel_size, dilation=dilation, padding=0)
    def forward(self, x):
        x = torch.nn.functional.pad(x, (self.pad, 0))
        return self.conv(x)


class RULModel(torch.nn.Module):
    """ Contains a CNN fed by Esw, an LSTM fed by Rth and Vt, and a cross attention layer that combines the CNN and LSTM outputs to predict RUL. """
    def __init__(self, input_size: int, hidden_size: int, num_layers: int):
        super(RULModel, self).__init__()
        self.cnnconv1=    CausalConv1d(in_channels=1, out_channels=hidden_size, kernel_size=5, dilation=8)
        self.cnnconv2=    CausalConv1d(in_channels=hidden_size, out_channels=hidden_size, kernel_size=3, dilation=1)
        self.cnnrelu =    torch.nn.ReLU()
        self.cnnbn = torch.nn.BatchNorm1d(hidden_size)
        self.lstm = torch.nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.attention = torch.nn.MultiheadAttention(embed_dim=hidden_size, num_heads=1, batch_first=True)
        self.fc = torch.nn.Linear(hidden_size, 1)

        self.cm_scale = torch.nn.Linear(1, 1)  # Scaling factor for coffin-manson predictions
        self.cm_material = torch.nn.Linear(1, 1)  # Scaling factor for coffin-manson predictions

    def forward(self, esw, rth_vt):
        # CNN branch for Esw
        # esw = esw.permute(0,2,1)  # Add channel dimension; suggested by Gemini
        # esw = esw.unsqueeze(1)  # Add channel dimension
        esw = esw.view(esw.size(0), 1, -1)  # Reshape to (1, 1, seq_len)
        rth_vt = rth_vt.view(rth_vt.size(0), -1, 2)  # Add batch dimension for LSTM

        cnn_out = self.cnnconv1(esw)
        cnn_out = self.cnnrelu(cnn_out)
        # cnn_out = self.cnnconv2(cnn_out)
        # cnn_out = self.cnnrelu(cnn_out)
        cnn_out = self.cnnbn(cnn_out)
        cnn_out = cnn_out.transpose(1,2)  # (batch, seq_len, hidden_size)
        
        # LSTM branch for Rth and Vt
        lstm_out, _ = self.lstm(rth_vt)
        
        # Cross attention between CNN and LSTM outputs
        seq_len = cnn_out.size(1)
        causal_mask = torch.triu(  # Causal mask from Claude
            torch.ones(seq_len, seq_len, device=cnn_out.device), diagonal=1
        ).bool()  # True = masked out

        attn_output, _ = self.attention(
            cnn_out, lstm_out, lstm_out,
            attn_mask=causal_mask
        )
        
        # Final RUL prediction using fused attention output
        rul_pred = self.fc(attn_output)  # Per-timestep predictions: (batch, seq_len, 1)
        
        return rul_pred

# %%
zpo = torch.tensor([0.1], device=device)

def train_model(model, data_train, data_dev, num_epochs=100, learning_rate=0.001, fancyloss=False):

    # Init weights to reasonable values so fancy loss is not at a disadvantage.
    torch.nn.init.constant_(model.cm_material.weight, -2.5)
    torch.nn.init.constant_(model.cm_material.bias, 0.0)
    # Initialize cm_scale to identity (slope=1, bias=0)
    torch.nn.init.constant_(model.cm_scale.weight, 1e6)
    torch.nn.init.constant_(model.cm_scale.bias, 0.0)


    mseloss = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    allloss = []

    # move things to the device:
    model.to(device)
    mseloss.to(device)
    # data_dev = data_dev.to(device)
    # data_train = [d.to(device) for d in data_train]

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for device_data in data_train:
            # window_size = np.random.randint(256, 2048)  # Random window size
            # Claude helped with trasforming my code from individual runs to batching, which speeds things up tremendously!
            # i=0
            # esw_batch = torch.stack([
            #     torch.tensor(device_data.iloc[i:i+window_size]['Esw'].values, dtype=torch.float32)
            #     for window_size in range(8, len(device_data))
            # ]).to(device)  # (batch_size, window_size)
            
            # rth_vt_batch = torch.stack([
            #     torch.tensor(device_data.iloc[i:i+window_size][['Rth', 'Delta_Vt']].values, dtype=torch.float32)
            #     for window_size in range(8, len(device_data))
            # ]).to(device)  # (batch_size, window_size, 2)
            
            # rul_batch = torch.tensor([
            #     device_data.iloc[i+window_size-1]['RUL'] / rul_scale
            #     for window_size in range(8, len(device_data))
            # ], dtype=torch.float32).to(device)  # (batch_size,)

            esw = torch.tensor(device_data['Esw'].values, dtype=torch.float32).unsqueeze(0).to(device)
            rth_vt = torch.tensor(device_data[['Rth', 'Delta_Vt']].values, dtype=torch.float32).unsqueeze(0).to(device)

            # Get rul at the end of the window
            # rul = torch.tensor(device_data_window.iloc[-1]['RUL'], dtype=torch.float32).to(device) / rul_scale  # Normalize RUL to be between 0 and 1

            optimizer.zero_grad()
            # rul_pred = model(esw_batch, rth_vt_batch)
    
            rul_pred = model(esw, rth_vt)
            rul_true = torch.tensor(device_data['RUL'].values / rul_scale, dtype=torch.float32).to(device)  # (N,)
            
            # Use coffin-manson model
            # Subtract 25 degC from a sliding average of package temperature to get deltaT
            deltaT = torch.tensor(device_data['time_domain_packageTemperature'].values, dtype=torch.float32).to(device) - 25
            A = .1 if not fancyloss else model.cm_scale(zpo)
            alpha = model.cm_material(torch.tensor([1.0], device=device)) if fancyloss else -2.5 # Learnable material parameter
            Nf = (A * torch.pow(deltaT.unsqueeze(-1) , alpha))/ rul_scale

            loss = 0.7 * mseloss(rul_pred.squeeze(), rul_true) + 0.3 * mseloss(rul_pred.squeeze() , (Nf.view(-1, 1)).squeeze())
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        # Evaluate on development set (full sequence like training)
        model.eval()
        dev_loss = 0.0
        with torch.no_grad():
            data_dev_window = data_dev

            esw_dev = torch.tensor(data_dev_window['Esw'].values, dtype=torch.float32).unsqueeze(0).to(device)
            rth_vt_dev = torch.tensor(data_dev_window[['Rth', 'Delta_Vt']].values, dtype=torch.float32).unsqueeze(0).to(device)

            # Get full RUL sequence for dev set (not just final value)
            rul_dev_full = torch.tensor(data_dev_window['RUL'].values / rul_scale, dtype=torch.float32).to(device)
            rul_pred_dev = model(esw_dev, rth_vt_dev)

            # Use coffin-manson model
            # Subtract 25 degC from a sliding average of package temperature to get deltaT
            deltaT = torch.tensor(data_dev_window['time_domain_packageTemperature'].values, dtype=torch.float32).to(device) - 25
            A = .1 if not fancyloss else model.cm_scale(zpo)
            alpha = model.cm_material(torch.tensor([1.0], device=device)) if fancyloss else -2.5  # Learnable material parameter
            Nf = (A * torch.pow(deltaT.unsqueeze(-1), alpha))/ rul_scale

            # Compute loss over full sequence like training
            dev_loss = 0.7 * mseloss(rul_pred_dev.squeeze(), rul_dev_full) + 0.3 * mseloss(rul_pred_dev.squeeze()  , (Nf.view(-1, 1)).squeeze())

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss/len(data_train):.4f}, Dev Loss: {dev_loss:.4f}")
        allloss += [(train_loss/len(data_train), dev_loss/len(data_dev))]

    return allloss

# %%
modela = RULModel(input_size=2, hidden_size=32, num_layers=2)
modelb = RULModel(input_size=2, hidden_size=32, num_layers=2)
modelb.load_state_dict(modela.state_dict())  # Start with same weights for fair comparison

lossa = train_model(modela, data_train, data_dev, num_epochs=256, learning_rate=0.0005, fancyloss=False)
lossb = train_model(modelb, data_train, data_dev, num_epochs=256, learning_rate=0.0005, fancyloss=True)
# Out:
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 1/256, Train Loss: 0.0853, Dev Loss: 0.0718
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 2/256, Train Loss: 0.0769, Dev Loss: 0.0644
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 3/256, Train Loss: 0.0694, Dev Loss: 0.0576
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 4/256, Train Loss: 0.0625, Dev Loss: 0.0514
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 5/256, Train Loss: 0.0559, Dev Loss: 0.0456
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 6/256, Train Loss: 0.0499, Dev Loss: 0.0405
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 7/256, Train Loss: 0.0446, Dev Loss: 0.0366
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 8/256, Train Loss: 0.0406, Dev Loss: 0.0345
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 9/256, Train Loss: 0.0384, Dev Loss: 0.0343
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 10/256, Train Loss: 0.0381, Dev Loss: 0.0352
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 11/256, Train Loss: 0.0387, Dev Loss: 0.0355
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 12/256, Train Loss: 0.0386, Dev Loss: 0.0346
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 13/256, Train Loss: 0.0376, Dev Loss: 0.0333
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 14/256, Train Loss: 0.0366, Dev Loss: 0.0323
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 15/256, Train Loss: 0.0357, Dev Loss: 0.0317
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 16/256, Train Loss: 0.0351, Dev Loss: 0.0312
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 17/256, Train Loss: 0.0344, Dev Loss: 0.0306
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 18/256, Train Loss: 0.0335, Dev Loss: 0.0297
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 19/256, Train Loss: 0.0323, Dev Loss: 0.0286
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 20/256, Train Loss: 0.0310, Dev Loss: 0.0274
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 21/256, Train Loss: 0.0297, Dev Loss: 0.0261
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 22/256, Train Loss: 0.0288, Dev Loss: 0.0251
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 23/256, Train Loss: 0.0282, Dev Loss: 0.0246
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 24/256, Train Loss: 0.0279, Dev Loss: 0.0247
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 25/256, Train Loss: 0.0276, Dev Loss: 0.0252
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 26/256, Train Loss: 0.0276, Dev Loss: 0.0258
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 27/256, Train Loss: 0.0276, Dev Loss: 0.0261
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 28/256, Train Loss: 0.0275, Dev Loss: 0.0260
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 29/256, Train Loss: 0.0274, Dev Loss: 0.0256
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 30/256, Train Loss: 0.0273, Dev Loss: 0.0252
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 31/256, Train Loss: 0.0272, Dev Loss: 0.0249
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 32/256, Train Loss: 0.0272, Dev Loss: 0.0247
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 33/256, Train Loss: 0.0271, Dev Loss: 0.0246
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 34/256, Train Loss: 0.0271, Dev Loss: 0.0246
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 35/256, Train Loss: 0.0271, Dev Loss: 0.0246
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 36/256, Train Loss: 0.0270, Dev Loss: 0.0246
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 37/256, Train Loss: 0.0270, Dev Loss: 0.0245
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 38/256, Train Loss: 0.0269, Dev Loss: 0.0244
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 39/256, Train Loss: 0.0269, Dev Loss: 0.0243
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 40/256, Train Loss: 0.0269, Dev Loss: 0.0243
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 41/256, Train Loss: 0.0268, Dev Loss: 0.0242
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 42/256, Train Loss: 0.0268, Dev Loss: 0.0242
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 43/256, Train Loss: 0.0268, Dev Loss: 0.0242
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 44/256, Train Loss: 0.0268, Dev Loss: 0.0242
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 45/256, Train Loss: 0.0267, Dev Loss: 0.0242
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 46/256, Train Loss: 0.0267, Dev Loss: 0.0241
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 47/256, Train Loss: 0.0267, Dev Loss: 0.0241
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 48/256, Train Loss: 0.0267, Dev Loss: 0.0240
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 49/256, Train Loss: 0.0266, Dev Loss: 0.0240
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 50/256, Train Loss: 0.0266, Dev Loss: 0.0240
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 51/256, Train Loss: 0.0266, Dev Loss: 0.0239
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 52/256, Train Loss: 0.0266, Dev Loss: 0.0239
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 53/256, Train Loss: 0.0266, Dev Loss: 0.0239
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 54/256, Train Loss: 0.0265, Dev Loss: 0.0239
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 55/256, Train Loss: 0.0265, Dev Loss: 0.0239
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 56/256, Train Loss: 0.0265, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 57/256, Train Loss: 0.0265, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 58/256, Train Loss: 0.0265, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 59/256, Train Loss: 0.0265, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 60/256, Train Loss: 0.0264, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 61/256, Train Loss: 0.0264, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 62/256, Train Loss: 0.0264, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 63/256, Train Loss: 0.0264, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 64/256, Train Loss: 0.0264, Dev Loss: 0.0238
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 65/256, Train Loss: 0.0264, Dev Loss: 0.0237
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 66/256, Train Loss: 0.0264, Dev Loss: 0.0237
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 67/256, Train Loss: 0.0263, Dev Loss: 0.0237
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 68/256, Train Loss: 0.0263, Dev Loss: 0.0237
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 69/256, Train Loss: 0.0263, Dev Loss: 0.0237
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 70/256, Train Loss: 0.0263, Dev Loss: 0.0237
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 71/256, Train Loss: 0.0263, Dev Loss: 0.0237
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.800945058169859e-11 1.225413104322115e-09
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 5.556081289492809e-11 1.0889600332575355e-09
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: None
# alpha grad: None
# A value: 0.1
# alpha value: -2.5
# Nf range: 4.5644963503344016e-11 1.0561870267267182e-09
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 72/256, Train Loss: 0.0263, Dev Loss: 0.0237
# A grad: None
# alpha grad: None
# A value: 0.1
# ...
# A grad: tensor([[1.0257e-09]], device='cuda:0')
# alpha grad: tensor([[0.0060]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0248], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.16717448830604553 0.6059775948524475
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 243/256, Train Loss: 0.0030, Dev Loss: 0.0051
# A grad: tensor([[3.6330e-09]], device='cuda:0')
# alpha grad: tensor([[0.0161]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0245], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17101815342903137 0.6450435519218445
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-9.1682e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0455]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0242], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1818268597126007 0.6152666807174683
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[3.2982e-10]], device='cuda:0')
# alpha grad: tensor([[0.0028]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0238], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1681586652994156 0.6087374091148376
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 244/256, Train Loss: 0.0029, Dev Loss: 0.0109
# A grad: tensor([[7.9338e-09]], device='cuda:0')
# alpha grad: tensor([[0.0389]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0234], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17202994227409363 0.6479655504226685
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-8.4610e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0411]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0232], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18280014395713806 0.6178438663482666
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[-3.5971e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0168]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0229], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.16897690296173096 0.6110289692878723
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 245/256, Train Loss: 0.0030, Dev Loss: 0.0064
# A grad: tensor([[4.0169e-09]], device='cuda:0')
# alpha grad: tensor([[0.0188]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0225], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17285770177841187 0.6503530144691467
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-5.0705e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0242]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0223], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1837529093027115 0.620363712310791
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[2.4810e-09]], device='cuda:0')
# alpha grad: tensor([[0.0132]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0219], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.16987165808677673 0.6135320663452148
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 246/256, Train Loss: 0.0028, Dev Loss: 0.0068
# A grad: tensor([[7.1701e-09]], device='cuda:0')
# alpha grad: tensor([[0.0335]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0217], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1736464947462082 0.6526256799697876
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-7.1034e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0352]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0216], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18440154194831848 0.6220776438713074
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[-1.8775e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0089]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0214], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17037184536457062 0.6149300932884216
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 247/256, Train Loss: 0.0028, Dev Loss: 0.0063
# A grad: tensor([[5.3358e-09]], device='cuda:0')
# alpha grad: tensor([[0.0248]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0212], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1741490513086319 0.6540723443031311
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-3.6624e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0167]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0211], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18496151268482208 0.6235562562942505
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[1.0691e-09]], device='cuda:0')
# alpha grad: tensor([[0.0066]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0209], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17084792256355286 0.6162598133087158
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 248/256, Train Loss: 0.0029, Dev Loss: 0.0060
# A grad: tensor([[4.7885e-09]], device='cuda:0')
# alpha grad: tensor([[0.0221]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0208], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17452435195446014 0.6551520824432373
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-7.6455e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0377]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0208], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18526406586170197 0.6243547201156616
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[-6.3436e-10]], device='cuda:0')
# alpha grad: tensor([[-0.0026]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0206], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17114000022411346 0.6170751452445984
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 249/256, Train Loss: 0.0028, Dev Loss: 0.0076
# A grad: tensor([[7.3844e-09]], device='cuda:0')
# alpha grad: tensor([[0.0350]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0204], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17486806213855743 0.6561404466629028
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-5.2032e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0251]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0204], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18561223149299622 0.6252732276916504
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[1.1073e-09]], device='cuda:0')
# alpha grad: tensor([[0.0066]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0203], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17140351235866547 0.6178104877471924
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 250/256, Train Loss: 0.0027, Dev Loss: 0.0071
# A grad: tensor([[5.7473e-09]], device='cuda:0')
# alpha grad: tensor([[0.0272]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0203], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17504042387008667 0.6566359400749207
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-7.9125e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0387]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0203], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18573687970638275 0.6256019473075867
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[-1.3579e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0057]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0202], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17152859270572662 0.6181595325469971
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 251/256, Train Loss: 0.0027, Dev Loss: 0.0074
# A grad: tensor([[6.1066e-09]], device='cuda:0')
# alpha grad: tensor([[0.0291]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0201], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1752265989780426 0.6571710109710693
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-5.3119e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0254]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0201], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18598014116287231 0.6262434124946594
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[1.1177e-09]], device='cuda:0')
# alpha grad: tensor([[0.0066]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0200], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17174221575260162 0.6187554001808167
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 252/256, Train Loss: 0.0027, Dev Loss: 0.0066
# A grad: tensor([[6.3428e-09]], device='cuda:0')
# alpha grad: tensor([[0.0298]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0199], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17537936568260193 0.6576099395751953
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-6.8091e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0334]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0200], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18607647716999054 0.6264973282814026
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[-6.5188e-10]], device='cuda:0')
# alpha grad: tensor([[-0.0025]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0199], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17181123793125153 0.6189478635787964
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 253/256, Train Loss: 0.0027, Dev Loss: 0.0066
# A grad: tensor([[6.2536e-09]], device='cuda:0')
# alpha grad: tensor([[0.0294]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0198], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17546838521957397 0.6578656435012817
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-4.9415e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0235]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0199], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18618926405906677 0.626794695854187
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[6.6530e-10]], device='cuda:0')
# alpha grad: tensor([[0.0045]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0198], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17189238965511322 0.6191741228103638
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 254/256, Train Loss: 0.0027, Dev Loss: 0.0063
# A grad: tensor([[5.5858e-09]], device='cuda:0')
# alpha grad: tensor([[0.0262]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0198], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1754991114139557 0.6579539775848389
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-6.8310e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0333]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0199], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.18618658185005188 0.6267876029014587
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[-5.3600e-10]], device='cuda:0')
# alpha grad: tensor([[-0.0017]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0198], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1719006896018982 0.6191973090171814
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 255/256, Train Loss: 0.0026, Dev Loss: 0.0068
# A grad: tensor([[6.4383e-09]], device='cuda:0')
# alpha grad: tensor([[0.0304]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0197], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17554354667663574 0.6580815315246582
# rul_true range: 0.0 0.5130000114440918
# deltaT range: 69.86746978759766 255.3038330078125
# A grad: tensor([[-5.5973e-09]], device='cuda:0')
# alpha grad: tensor([[-0.0270]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0198], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.1862487941980362 0.6269516348838806
# rul_true range: 0.0 0.6579999923706055
# deltaT range: 73.24588775634766 240.8133544921875
# A grad: tensor([[8.3394e-10]], device='cuda:0')
# alpha grad: tensor([[0.0052]], device='cuda:0')
# A value: tensor([100000.2734], device='cuda:0', grad_fn=<ViewBackward0>)
# alpha value: tensor([-1.0198], device='cuda:0', grad_fn=<ViewBackward0>)
# Nf range: 0.17194606363773346 0.6193238496780396
# rul_true range: 0.0 0.5630000233650208
# deltaT range: 74.14667510986328 260.5138854980469
# Epoch 256/256, Train Loss: 0.0026, Dev Loss: 0.0067

# %%
# plot train, dev loss on separate y-axes:
plt.title("Train and Dev Loss Over Epochs")
plt.xlabel("Epoch")
plt.plot([l[0] for l in lossa], label="Train Loss, Vanilla", linestyle='--', color='orange')
plt.plot([l[0] for l in lossb], label="Train Loss, Multiple Dilation", linestyle='--', color='red')
plt.ylabel("Train Loss")
plt.twinx()
plt.plot([l[1].cpu() for l in lossa], label="Original Model", color='orange')
plt.plot([l[1].cpu() for l in lossb], label="Adaptively Fit Loss Function", color='red')
plt.ylabel("Dev Loss")
plt.legend(loc="upper right")
plt.grid()
plt.show()

# %%
modela.eval()
modelb.eval()
with torch.no_grad():
    esw_dev = torch.tensor(data_dev['Esw'].values, dtype=torch.float32).unsqueeze(0).to(device)
    rth_vt_dev = torch.tensor(data_dev[['Rth', 'Delta_Vt']].values, dtype=torch.float32).unsqueeze(0).to(device)
    
    rula_pred_dev = modela(esw_dev, rth_vt_dev)  # (1, seq_len, 1)
    rulb_pred_dev = modelb(esw_dev, rth_vt_dev)  # (1, seq_len, 1)
    rul_true_dev = data_dev['RUL'].values  # (seq_len,)
    rula_pred_values = rula_pred_dev.squeeze().cpu().numpy() * rul_scale  # (seq_len,)
    rulb_pred_values = rulb_pred_dev.squeeze().cpu().numpy() * rul_scale  # (seq_len,)

# Also plot predicted and true side by side over time
plt.figure(figsize=(12, 6))
plt.plot(data_dev['time'], rul_true_dev, label="True RUL")
plt.plot(data_dev['time'], rula_pred_values, label="Predicted RUL (Original)")
plt.plot(data_dev['time'], rulb_pred_values, label="Predicted RUL (Adaptive Loss Funtion)")
plt.xlabel("Time (s)")
plt.ylabel("RUL")
plt.legend()
plt.title("Predicted and True RUL Over Time on \"Development Set\" Device")
plt.grid()
plt.show()
